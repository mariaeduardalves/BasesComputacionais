# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaeduardalves/BasesComputacionais/blob/master/Tarefa17MariaEduardaAlves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 17
#
# Maria Eduarda Vieira da Silva Alves
#
# RA: 11202231058

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
brasileirao = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/f2740361de0c972edfa8f878935d282025732213/dados/tabelaBrasileirao2018.csv')
brasileirao
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 0    14/04/2018      1         Cruzeiro                   0
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante        Visitante  \
# 0                      1           Grêmio
# 1                      2         Flamengo
# 2                      0            Ceará
# 3                      0            Sport
# ...

# %%
plt.figure()
plt.plot(brasileirao['Público'], brasileirao["Renda (R$)"], "o")
plt.show()

# %%
brasileirao["Renda (R$)"].corr(brasileirao['Público'])
# Out:
# 0.8365730756690009
